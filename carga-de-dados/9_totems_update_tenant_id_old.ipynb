# %%
pip install pymssql && pip install mysql-connector && pip install pyodbc
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pymssql in c:\users\ok\appdata\roaming\python\python311\site-packages (2.2.7)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: mysql-connector in c:\users\ok\appdata\roaming\python\python311\site-packages (2.2.9)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pyodbc
#   Downloading pyodbc-4.0.35-cp311-cp311-win_amd64.whl (66 kB)
#      ---------------------------------------- 0.0/66.0 kB ? eta -:--:--
#      ---------------------------------------- 66.0/66.0 kB 3.5 MB/s eta 0:00:00
# Installing collected packages: pyodbc
# Successfully installed pyodbc-4.0.35
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymssql
import mysql.connector
import pyodbc
import uuid
from datetime import datetime, date, time, timezone
import re


print('Hora:' + str(datetime.now()))
print('------------==== Iniciando ====------------')

# Conectar ao MySQ
mydb = pyodbc.connect(
    'DRIVER={MySQL ODBC 8.0 ANSI Driver};User=b917ff59ce1d97;Password=25c54e44;Server=us-cdbr-east-06.cleardb.net;Database=heroku_83e62f327577c35;')
    # 'DRIVER={MySQL ODBC 8.0 ANSI Driver};User=b4f8033d37e8e8;Password=c4f88825;Server=us-cdbr-east-06.cleardb.net;Database=heroku_d67bbb63764a109;')
cursor = mydb.cursor()
query = 'select t.tenant_id_old, t.tenant_id,  t.* from heroku_83e62f327577c35.totems t'
cursor.execute(query)
totems = cursor.fetchall()
loop = 1
for totem in totems:

    id_totem = totem[2]
    id_old_unidade = totem[0]
    queryUnidades = f'SELECT u.id_old, u.id,  u.* FROM heroku_83e62f327577c35.unidades u where u.id_old = {id_old_unidade}'
    cursor.execute(queryUnidades)
    todasUnidades = cursor.fetchall()

    for unidade in todasUnidades:
        tenant_id_atual = unidade[1]

    update = f"UPDATE totems set tenant_id = {tenant_id_atual} WHERE id = '{id_totem}'"
    cursor.execute(update)
    print('Loop: ' + str(loop))
    loop += 1
    # mydb.commit()

# Confirmar as alterações no MySQL
mydb.commit()
print('------------==== Finalizado ====------------')

# Desconectar do MySQL
mydb.close()
# Out:
# Hora:2023-02-28 19:18:00.748913
# ------------==== Iniciando ====------------
# Loop: 1
# Loop: 2
# Loop: 3
# Loop: 4
# Loop: 5
# Loop: 6
# Loop: 7
# Loop: 8
# Loop: 9
# Loop: 10
# Loop: 11
# Loop: 12
# Loop: 13
# Loop: 14
# Loop: 15
# Loop: 16
# Loop: 17
# Loop: 18
# Loop: 19
# Loop: 20
# Loop: 21
# Loop: 22
# Loop: 23
# Loop: 24
# Loop: 25
# Loop: 26
# Loop: 27
# Loop: 28
# Loop: 29
# Loop: 30
# Loop: 31
# Loop: 32
# Loop: 33
# Loop: 34
# Loop: 35
# Loop: 36
# Loop: 37
# Loop: 38
# Loop: 39
# Loop: 40
# Loop: 41
# Loop: 42
# Loop: 43
# Loop: 44
# Loop: 45
# Loop: 46
# Loop: 47
# Loop: 48
# Loop: 49
# Loop: 50
# Loop: 51
# Loop: 52
# Loop: 53
# Loop: 54
# Loop: 55
# Loop: 56
